# %%
import torch
import torch.nn.functional as F
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification, AdamW, set_seed

# %%
PATH = "./entire_model.pt"
BERT_MODEL = 'bert-base-uncased' # BERT model name for Transformer
MAX_LENGTH = 90
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # Check for GPU
BATCH_SIZE = 128

# %%
model = torch.load(PATH)
model.eval()

tokenizer = AutoTokenizer.from_pretrained(BERT_MODEL)

# %%
df = pd.read_csv('./data/analysis/Right_clean.csv')

# %%
df['tweet_text']
# Out:
# 0       trump first ran president hard many imagine ro...
# 1       trishregan left realize secret service always ...
# 2                                dbongino good luck buddy
# 3       jaltucher feel like need restraining order guy...
# 4       msm might want look actual stats cdc next time...
#                               ...
# 3671    breaking biden begins staffing commission aime...
# 3672              cloris leachman legendary actress dead
# 3673    biden says impose equity see susan rice charge...
# 3674    bidens shaken teachers union tell teachers tea...
# 3675    clean energy solar wind make  energy portfolio...
# Name: tweet_text, Length: 3676, dtype: object

# %%
def get_output(texts):
    tokens = tokenizer(
            texts,
            padding='max_length',
            max_length=MAX_LENGTH,
            truncation=True,
            return_tensors="pt"
        )

    input_ids = tokens['input_ids'].to(device)
    attention_mask = tokens['attention_mask'].to(device)
    # labels = tokens['labels'].to(device)

    input_ids, attention_mask
    output = model(input_ids, attention_mask=attention_mask)
    yhat = output.logits

    yhat = F.softmax(yhat, dim=1)
    yhat = torch.argmax(yhat, dim=1)

    return ["Hate" if x else "Not Hate" for x in yhat.tolist()]

# %%
FILE_PATH = './data/analysis/'

for file in ['Right', "Left", "Fake"]:
    filename = FILE_PATH + file + '_clean.csv'
    df = pd.read_csv(filename)
    tweets = list(df['tweet_text'])
    print(len(tweets))
    res = []
    i = 0
    while i < len(tweets):
        res += get_output(tweets[i : i+BATCH_SIZE])
        i += BATCH_SIZE
    
    df["label"] = res
    df.to_csv(FILE_PATH + file + '_labeled.csv')
    
    df.label.value_
# Out:
# 3676
# 3788
# 8385

# %%
list(df['tweet_text'])
# Out:
# ['trump first ran president hard many imagine role dilbert creator',
#  'trishregan left realize secret service always president even hospital room even ho',
#  'dbongino good luck buddy',
#  'jaltucher feel like need restraining order guy wish would address actual problems gotten',
#  'msm might want look actual stats cdc next time insist realdonaldtrump americ',
#  'mccormickprof idea social tolerance experimentone would also make good reality tv would film volunteer wearin',
#  'rickygervais remembered life insignificant blip eternal void nothingness',
#  'people think answer unelected get away longer',
#  'thebabylonbee monster releases exciting new energy drink infused trump antibodies',
#  'thank mzhemingway need names details seem important missing',
#  'peoples champion',
#  'medias mad trump endangering secret service driving around block oh come onthat',
#  'kaysmythe please read listen share interview reflections tomilahren lavagrants larryoconnor drdrew foxnation r',
#  'great paint expect law enforcement officers come save asses east nash',
#  'media left know sad die least get sick everyone el',
#  'happy realdonaldtrump flotus join millions around world praying',
#  'cuomo keeps auto correcting clump could also work says last  seconds clip going hav',
#  'know joking nickgillespie billkristol believe free markets touting bide',
#  'vote realdonaldtrump   like alone could vote',
#  'left angry donald trump spent less time hospitalized coronavirus joe biden spent locke',
#  'trump wartime president like general gets wounded invisible enemy gets patched',
#  'special announcement emma baby way',
#  'johnnyjoey man alive today relentless work men women saving lives hell blin',
#  'hmm wonder new york times realize black bloc organized often violent insurrectionary',
#  'great resilient recovery made potus realdonaldtrump shows need reopen count',
#  'get ready libs winning beginning final thoughts',
#  'might well carry purse mask joe',
#  'susanshelley parody really office governor state california dining keep',
#  'thanks much',
#  'point honestly think joebiden wants president bad self sabotage',
#  'going cower covid yes take precautions americans let fear control lives',
#  'blazetv new report said   people worldwide likely infected covid true death rate th',
#  'paging johncoopernash',
#  'joe biden take socialist primaries socialist took left thefive',
#  'positive american spirit leftit exist running agai',
#  'kamala answered questions policy last two months well prepared',
#  'ajwimsatt greggutfelds excellent tribute eddie van halen thefive rip eddie',
#  'days comfortable religious person quickly coming end world call faithfulness',
#  'comicdavesmith finally getting specific policy',
#  'timrunshismouth someone taught katie hill two factor authentication something try husband',
#  'look aoc going true patriot cawthornfornc ready fight freedom coming way',
#  'join aoc tonight',
#  'conservmillen stevedeaceshow rubinreport donaldjtrumpjr also joining debate',
#  'jimmyfailla best protrump ad I ever seen',
#  'realdonaldtrump authorizing declassification documents related russia probe hillary clintons',
#  'check amazing new podcast legendary chilly gonzales awesome',
#  'kamala harris liked many democrats primaries expect liked many americans wa',
#  'washington saying  trillion dollars much get accused high drugs thefive',
#  'devious effective political smear campaign modern american history thefive',
#  'please realize division america think vast majority americans sides',
#  'bailouts blue states refuse reopen',
#  'wonder ask kamala still thinks biden racist',
#  'wonder ask kamala covered catholic clergy sexual abuse da',
#  'richardgrenell famous sings men choses turn losers',
#  'wonder ask kamala proud jacob blake  la deputies shot face ambush state ca',
#  'standing behind plexiglass tonights post vpdebate analysis stand behind plexiglass tune find',
#  'wonder ask kamala banking potus since already refers harris admin',
#  'look californiaif kamala worth damn state would crap hole committed',
#  'wonder ask kamala boasted smoking weed listening tupac tupac put record',
#  'democrats elected infringements continue',
#  'never forget trump closed travel land china virus dems called racist',
#  'never forget democrats still focused witch hunt china virus popping',
#  'kamala answer questionare going lockdown shutdown mask mandate answer question',
#  'kamala would answer question harris admin continue lockdowns shutdowns national mask',
#  'amazing dig mike hahaha',
#  'serious want dems want ban travel china',
#  'guys still want students go back people go back work',
#  'guess people going get virus fact matter lock forever',
#  'democrats trust americans think need controlled like sheep',
#  'freedom vs control voting november',
#  'would nice democrat tyrants would told us planned  months flatten curve',
#  'joe biden inauguration day',
#  'ask refers harris admin',
#  'joe biden hidden freakin basement',
#  'm hunter biden',
#  'joe make decisions charge ukraine policy based interest american people hunters pocket book',
#  'joe biden get rid tax cuts',
#  'federal government never innovated anything private sector freedom capitalism creates innovation',
#  'better way invest american people allowing keep earn',
#  'kamala operate talking points rehearsed lines cannot answer question',
#  'well obamacare thing workout',
#  'someone frazzled guy looks like escaped franklin mint',
#  'kamala loves green new deal older aoc less instagram followers',
#  'maybe environmental cult would allow tree clearing would tinder freakin box',
#  'kat acts like pence rude responds working making appear sympathetic',
#  'joe abolish fossil fuels',
#  'pence smooth could bris head recommend',
#  'rubinreport joe stuff last  years',
#  'answer record kamala',
#  'pence crushing',
#  'continues crush headlines read pence sexist',
#  'hunter knows lot relationships',
#  'seanonolennon also someone elses',
#  'kamala answering questions saying shit told say throwing shit',
#  'repeat tds antitrump lines talk policy usual one neither joe',
#  'let guy respond jesus page',
#  'military loves trump',
#  'allow rebuttal personal claims made moral character see wha',
#  'kamala says one time rbg wanted I going barf',
#  'susan page saved kamala',
#  'ask kamala supports packing court',
#  'interested well known catholics explaining joe strong catholic proabortion I seriously willing listen',
#  'thing fear mongering repeating',
#  'yes answer question kamala',
#  'marylynnrajskub intellectual answer tried',
#  'answering question ah page needs let pence respond',
#  'ask wants defund police',
#  'well prepared answer',
#  'lying pence allowed respond move',
#  'ah fine people lie transcript debunk thatoh yea',
#  'way harris mistreats female moderator seems sexist',
#  'note time tweet joke fly already',
#  'mailin voting opens door fraud',
#  'th graders asking debate questions',
#  'answer th grader go outside catch frogs',
#  'one says pence win lying',
#  'benshapiro pence thoroughly dismantled harris means media immediately declare harris messiah anoint',
#  'foxnation tomilahren hosts johnnyjoey ethanbearman scottwrasmussen react  vice presidential debate',
#  'kurtschlichter eightyearold asked maleidentifying parenting figure greggutfeld refuse accept validity',
#  'jane fonda says coronavirus gods gift left means given democratic',
#  'want live life scared choice rest us know lot lose continuing',
#  'comment necessary trumplandslide realdonaldtrump realcandaceo benshapiro marklevinshow',
#  'call racist xenophobic stopped travel china remember',
#  'kamala harris get away saying trump tanked economy remember like three year',
#  'young people psycho socialists patriots still exist',
#  'debate commission made second debate virtual take attention away masterclass debate pe',
#  'foxnewsradio theone greggutfeld grammy awardwinning mad genius chillygonzales shares drawn rap music',
#  'I sorry kamala harris little history lesson vp debate abraham lincoln real history linc',
#  'suburban wisconsin white supremacists struck like saw portland kenosha',
#  'marylynnrajskub dustinpg lesson asked sincere question twitter verse foolishness',
#  'never put psycho democrats saying realdonaldtrump accept results ele',
#  'trump keeps ordering doj release documents russia probe finally end hoax pa',
#  'dorisww dem rep see eye eye much civil convo friends check podcast tomi la',
#  'socialists america may claim want make us like scandinavia dineshdsouza explains ne',
#  'tomorrow mustsee watters world senator marcorubio former house speaker newtgingrich whitehouse',
#  'wattersworld tomorrow mustsee watters world senator marcorubio former house speaker newtgingrich whitehouse pressse',
#  'tvnewshq foxs greggutfeld media democrats lost right complain violence say wor',
#  'losers week kamala taylor swift jane fonda course nancy pelosi',
#  ' utahans would ever read paper senmikelee right trust thing deseretnews wr',
#  ' president lee mckay benson every prophet book manual church ever printed churc',
#  ' senators like harry reid stood would kill infants birth let alone',
#  ' know truth defend truth senmikelee attacked exposed',
#  ' sadly fallen asleep lost direction charge second last line defense r',
#  ' love deeply respect church leaders restored gospel true question th',
#  ' including faith disagree always chance heard never shou',
#  ' time exercise right god given responsibility stand truth',
#  ' steal freedoms rent coats need hoist title liberty high defend',
#  ' senmikelee stand leadership beloved prophet also compelled stand',
#  'danielmleclair senmikelee deseretnews tweet vulgar point truly shows lack',
#  ' people cannot rule unless taught true principles fear deseretnews knows end senmikelee',
#  'tonight usual time  pm show tasty might try crawl tv eat',
#  'watters world tonight jessebwatters newtgingrich marcorubio presssec kayleighmcenany',
#  'wattersworld watters world tonight jessebwatters newtgingrich marcorubio presssec kayleighmcenany jasoninthehou',
#  'election  days away state race former speaker house newtgingrich watter',
#  'wattersworld election  days away state race former speaker house newtgingrich watters wor',
#  'joe biden announce position court packingafter election senator marcorubio mustsee',
#  'yelp went helping diners find food destroying businesses place accused racism yelp put',
#  'wattersworld joe biden announce position court packingafter election senator marcorubio mustsee react',
#  'rustyrockets fair take always hijacking media forever manipulating us hold',
#  'secretary state mike pompeo says could hillary clinton emails released election',
#  'wattersworld secretary state mike pompeo says could hillary clinton emails released election whitehouse',
#  'declassified documents show obama knew hillary planned distract public email scandal vilify',
#  'redsteeze give future lawsuits  stars',
#  'wattersworld declassified documents show obama knew hillary planned distract public email scandal vilifying',
#  'undecided voters found kamala harris abrasive condescending vp debate pollster frankluntz wi',
#  'second debate moderator sent strange tweet mooch asking respond trumpbut claims h',
#  'wattersworld undecided voters found kamala harris abrasive condescending vp debate pollster frankluntz',
#  'wattersworld second debate moderator sent strange tweet mooch asking respond trumpbut claims',
#  'kayleighmcenany ignore bad quarantine shot looks coming  pm et wattersworld w jessebwatters',
#  'watters world one hour away jessebwatters newtgingrich marcorubio presssec kayleighmcenany',
#  'wattersworld watters world one hour away jessebwatters newtgingrich marcorubio presssec kayleighmcenany jasoninthe',
#  'watters world jessebwatters newtgingrich marcorubio presssec kayleighmcenany',
#  'wattersworld watters world jessebwatters newtgingrich marcorubio presssec kayleighmcenany jasoninthehouse',
#  'history proves marxism harmful societies still massive push gadsaad e',
#  'problems democrats solved done well watterswords',
#  'missed original airing watters world reair jessebwatters newtgingrich',
#  'wattersworld missed original airing watters world reair jessebwatters newtgingrich marcorubi',
#  'greggutfeldshow watch gregs latest monologue gutfeld',
#  'susanshelley real reason california reopening',
#  'anyone else notice dems talk socialist policies anymoremedicare gun confiscation',
#  'hollywood entertainment libs already crying realdonaldtrump victory biggest hypocrit',
#  'working lone rangers pants first six foot painting match next painting tonto',
#  'patrickscully scene',
#  'gadsaad explains one major difference president trump joe biden unlike biden political parasite',
#  'love dak',
#  'keithkjbucket ok understand celebrating lakers damn come got act like type class',
#  'happy columbus day',
#  'stevedeaceshow bidens mental state diminished even remember name one prominent supporters',
#  'patunleashed able help dad blazetvs thelaurenchen family would grateful thank considering h',
#  'thebabylonbee democrats hiss terror acb pulls crucifix',
#  'proof joe biden descendent slaveowners think sins family mean anything',
#  'amen recall tyrant',
#  'tvnewshq fox news jessebwatters weeks confirmation hearings amy going outsmart outclass outmanoeuvre',
#  'yelp start flagging businesses accused racist behavior antifa already preparing',
#  'repugnant useless rioters portland seattle never going stop airlift',
#  'thanks watching',
#  'foxnation madisoncawthorn tells tomilahren nointerruption america missing ability sit',
#  'sorry democrats filling rbgs supreme court seat amy coney barrett packing court called',
#  'biden voters show rallies show polls either though count dead',
#  'nypd chief patrol fausto pichardo resigned highest ranking latino member nypd antipolic',
#  'democrats concerned confirming amy coney barrett supreme court could end obamacare bu',
#  'sarahhuckabee judge barrett showed us supreme court kamala harris second line th',
#  'glfop brave men women law enforcement attacked ambushed across country want strong leader ba',
#  'governor bright future however told last week texan really bothers',
#  'case trump truly important election since  trump  man vs movement',
#  'acb liberal appointed liberal would cover every magazine lifted feminist pe',
#  'democrats listen new supreme court justices job uphold constitution obamas legacy',
#  'drrepstein noticed something concerning monitoring big techs influence election think thes',
#  'tried warn',
#  'apparent coordinated effort twitter facebook censor nypost article hunterbiden terrifying',
#  'newsletter one way get around censorship signed please',
#  'senator harris seems small right acb calmly dispensed predictable questions',
#  'corrupt company ukraine paying biden family biden helping corrupt company',
#  'americans look mess california vote harrisbiden takes nationwide vote smart vote person',
#  'noticed websites blogs edited men trying best find pics acb appe',
#  'democrats working overtime change voting rules across nation insisting nothing see',
#  'arytenoid yes',
#  'mcdonaldcomedy none us etch numbers airport bathroom stalls despicable pervert',
#  'democrats point man expand mailin voting nationwide guy behind al frankens headscratching',
#  'voting election crucial truethevotes catherine engelbrecht gave advice safest way',
#  'studoesamerica I afraid even tweet show tonight lest twitter overlords vengefully ban',
#  'donaldjtrumpjr bidens got rich america got robbed realdonaldtrump',
#  'twitter facebook showed us today chilling surprising working overtime diminish',
#  'sohrab joins radio show today digital civil war censor post',
#  'odd message twitter gave tried quote tweet sohrabahmaris story',
#  'interesting see stories trending happening two ukrainian stories la',
#  'gopoversight hey twitter try censoring ranking member repjamescomer oversight republicans called oversightdems',
#  'mattwalshblog facebook twitter really interested stopping misinformation would banned blm long time ago',
#  'mainstream media google facebook twitter realdonaldtrump media google faceb',
#  'twitter problem letting nyt trump tax return story go viral nypost censored hunter',
#  'saddest part google facebook twitter still better conservatives mainstream media',
#  'theblaze new york post opinion editor speaks big tech censors bombshell story hunter biden ukraine',
#  'joeconchatv aged well',
#  'fact losers left going tiffanyatrump nothing wrong sorry attempt distra',
#  'show obtained new hunter biden emails expose corruption want miss tonights report',
#  'hours senate democrats deemed sexual preference offensive term amy coney barretts hearing',
#  'things looking good trump campaign happy seeing democrat',
#  'townhall town savannah badgering joke',
#  'matter denounces guthrie find another proof denounces moves onto q see',
#  'guthrie even listening needs get thru list embarrassing',
#  'guthrie pretends questions many questions says chases narratives producers handed',
#  'nbc embarrassing worse expected guthrie like poorly disguised ambush even follows',
#  'I watching biden thing I watching trump thing think trump thing designed outbid',
#  'fact townhalls bs expected something better guthrie another irrational hack watch tucker',
#  'tonight joe getting softballs easy george trump getting attacked irrational guthrie hunter sifting pockets crack pipe',
#  'savanah new karen apologies karens',
#  'questions biden town hall contain sentiment biden agrees questions trump town ha',
#  'I glad trump agreed another debate realize would savannah guthrie',
#  'takes lot make trump look like bullied one savannahguthrie nailed flying colors',
#  'burisma told hunter wanted close casespursuits top official ukraine watch r',
#  'baldbryan egregious mistake rehab addiction blanket assumption uniform struggle',
#  'yet come',
#  'kirstenpowers misinterpreted fairly straightforward tweet worries try got time',
#  ' disappointed bensasse realdonaldtrump given us great judges lower court  judges far supe',
#  ' got us disastrous iran deal killed head terror boxed currently collapsi',
#  ' something president done even though promised yes met north korean dictator ha',
#  ' nato brought arabs jews together smashing choke hold plo stood ch',
#  ' I going cut slack bensasse also defended religious liberty unlike president',
#  ' made real roads open doors gop wussy even try open hispanics blacks ag',
#  ' realdonaldtrump also took economy beaten people told build th',
#  ' give us lowest unemployment rate since  year celebrated th birthday lowest unemployment',
#  ' largest pandemic  years things never seen president  americas biggest capi',
#  ' called racist xenophobic stirring hatred everyone says stood alo',
#  ' taking control companies telling wha produce simply asked free market step pla',
#  ' blamed blood bath created gov coumos nursing home policies said  million would',
#  ' seem hit best case scenario gone fought lies',
#  ' doj cia dept state fbi dni leave anyone oh yeah getting evidence',
#  ' would embarrass frank underwood also kevin spacey single handedly exposed pres',
#  ' enemies people hated first said true person group knowingly',
#  ' yeah bensasse done something fan someone support first',
#  ' stood entirely alone surrounded enemies surrounded took oath protect defend con',
#  ' spineless nothing old corrupt gop politicians either part problem frightened',
#  ' rang bell stood took hits risked lost money reputation perhaps',
#  ' history judge us childrens children forgotten failed',
#  'democrats trying hide prized socialist agenda called moderators media ask',
#  'rsscottbp walls work smugglers used drive across border area anymore',
#  'mattwalshblog children gotten used living world everyone wears masks never see peoples face public',
#  'instead trump town hall watched nbc news savannah guthrie debate realdonaldtrump meanwhile joe bide',
#  'tomorrow  days away election day jessebwatters live mustsee watters world tune foxnews',
#  'wattersworld tomorrow  days away election day jessebwatters live mustsee watters world tune foxnews pm',
#  'watch news america seems divided ever talked gym owner trainersethg bikin',
#  'show explosive warning  hours advance wear protective gear avoid shrapnel',
#  'celebrity endorsements candidates mattered hillary would president one cares',
#  'watters world live tonight jessebwatters mirandadevine pambondi cortessteve sentomcotton',
#  'wattersworld watters world live tonight jessebwatters mirandadevine pambondi cortessteve sentomcotton joeconchat',
#  'never going fair conservatives need fight harder better',
#  'joe biden identified big guy would receive percentage deal chinese energy firm new hu',
#  'joe biden finally asked reporter hunter biden email story see pambondi reacts tonight foxnews pm et',
#  'wattersworld joe biden finally asked reporter hunter biden email story see pambondi reacts tonight foxnews ',
#  'wattersworld joe biden identified big guy would receive percentage deal chinese energy firm new hunter b',
#  ' days election day hear trump  senior advisor cortessteve state race president',
#  'wattersworld  days election day hear trump  senior advisor cortessteve state race president trump',
#  'republican senators pushing answers twitter facebook censoring ny post story hunter bide',
#  'nbc criticized savannah guthrie debating president trump abc taking heat giving softballs joe bi',
#  'wattersworld republican senators pushing answers twitter facebook censoring ny post story hunter biden se',
#  'wattersworld nbc criticized savannah guthrie debating president trump abc taking heat giving softballs joe biden',
#  'confirmation hearings judge amy coney barrett weekbut catch bizarre moments',
#  'wattersworld confirmation hearings judge amy coney barrett weekbut catch bizarre moments raymo',
#  'holy hell',
#  'watters world live one hour jessebwatters mirandadevine pambondi cortessteve sentomcotton',
#  'wattersworld watters world live one hour jessebwatters mirandadevine pambondi cortessteve sentomcotton joecon',
#  'watters world live jessebwatters mirandadevine pambondi cortessteve sentomcotton joeconchatv',
#  'gotten point hatred president trump gotten bad people care anym',
#  'powerful interests aligned trump fighting side people people',
#  'wattersworld powerful interests aligned trump fighting side people people',
#  'tvnewshq fox news jessebwatters tide turning week changed race president trump course',
#  'I live chatting show go stop working twitter',
#  'greggutfeldshow watch gregs latest monologue gutfeld',
#  'greggutfeldshow missed last nights new gutfeld charleshurt emilycompagno kattimpf planettyrus reair',
#  'daily reminder liberalism disease',
#  'joe biden using left left using joe biden billoreilly put bluntly think joe biden',
#  'govkristinoem opening day full pheasant hunting season hunting',
#  'saturday m next chapter virtual event celebration  years work mercury one',
#  'slow joe asked gun control agenda latelydoes play well voters hmmm',
#  'donaldjtrumpjr presidential debates commission disgrace st chose biden intern fired lying h',
#  'leftist media stupid realize hate love trump',
#  'poor robert wants punish made irrelevant problem many',
#  'fr ed meeks brave homily election staring abyss via youtube',
#  'sliu rbreich first thought tweet stupid nonsensical read replies I even deeply scared eit',
#  'ny post get hunter bidens alleged hard drive congress fbi turned wo',
#  'cent said vote trump seeing slow joes tax rates let us go',
#  'even joe bidens campaign believe leading presidential race much polls say look',
#  'least president trump somewhere joe biden nowhere basement called lid  days',
#  'look early votebymail realdonaldtrump landslide making thefive',
#  'society want america one believes principles freedom one insists',
#  'got sell cocaine file claim',
#  'jamesmccoyt dems ripping tiffany trump today looks etc act like prowomen party kindness see dest',
#  'senate needs subpoena twitter ceo jack dorsey soon possible possible election interference censoring ny po',
#  'thanks much',
#  'hawleymo oh read bill truckloads cash blue state politicians leftwing donor interests bill mentions c',
#  'going cut president trumps mic debate also promise cut slow joes earpiece',
#  'longer good enough left get trump office going make sure never happens',
#  'bernie going run show senate bidens going sit let kamala dirty work',
#  'terminal threat biden campaign thefive',
#  'would bet lot democrat governors talking trash vaccine first line',
#  'dude declares lid  days yet tweets moronic platitudes spit weeks ago think really prepp',
#  'studoesamerica sick trump said fine people sides clearly racist argument seen fo',
#  'msm may dismiss ny posts hunter biden story peterschweizer thousands emails alleging hunter',
#  'nashville welcomes realdonaldtrump ready see dominate',
#  'jasonbuttrill fbi intelligence community agreement hunters laptop real par',
#  'dcexaminer would nice would members opposite side condemn many actions see politica',
#  'joegamaldi sgt harold preston murdered today cold blood trying help domestic violence victim f',
#  'suburban mom exactly dems worried november realized trump',
#  'streaming foxnation latest episode johnrich',
#  'psycho libs really think cent cares approval saving hardearned money',
#  'media warns another covid surge spoke republic assault author tomfitton real',
#  'quiet ones probably realdonaldtrump know',
#  'brand new podcast gadsaad brain eating wokism',
#  'feel good son vp selling access dad thefive',
#  'trump treat joe like treated hillary second debate  fact based methodical th',
#  'everywhere joe biden goes middle class gets hosed thefive',
#  'foxnation watch debate favorite fox nation personalities join tomilahren johnrich petehegseth tomorrow',
#  'turtle neck',
#  'media job tonight go straight source biggest story country ask',
#  'rudygiuliani argues hunter bidens alleged laptop absolutely provides evidence money flowing fami',
#  'past year I investigating hunter bidens odd business dealings ukraine china fathe',
#  'billfoxla breaking dni director john ratcliffe announces learned iran russia obtained us voter registratio',
#  'libs welcome pay bidens tax rates even trump reelected',
#  'I live nashville johnrich tomorrow morning amet foxandfriends',
#  'coming foxandfriends johnrich  mins',
#  'kilmeade tomilahren johnrich hosting live watching party final presidential debate tonight foxnation',
#  'losers think elite calling realdonaldtrump reality show president hey obama wor',
#  'antifa blm thugs think going pull something tonight nashvillei would tennessee',
#  'elect joe biden emails testimony show bed taking millions dollars chinese',
#  'elexmichaelson week theissueisshow first ever debate briantylercohen tomilahren looking forward respe',
#  'richardgrenell donaldjtrumpjr doubt together',
#  'watched trump  minutes segment first grateful get see stuff unedited bef',
#  'chuck schumer serious talk dianne feinstein progressives mad said amy con',
#  'holy crap add wakaflocka trump train list',
#  'donald trump debating kamala harris tonight broke today way joe biden b',
#  'joe biden using office cash register thefive',
#  'cbs news unprepared  minutes interview president trump thefive',
#  'liberal conceptualjames explained unhappily voting trump joe biden man captured',
#  'biden wants take control means biggest fear',
#  'joe even take care thinks almighty government take care',
#  'dark winter',
#  'cannot keep saying trump take seriously called racist cutting travel china',
#  'sooowe continue shutdowns joe yes',
#  'nancy friends busy russia witch hunt deal china virus',
#  'listen joe keep bars restaurants gyms closed',
#  'quote tweet',
#  'quote tweet',
#  'choice simple live fear get back normal scared stay home',
#  'joe wants leave bubble basement like campaign team makes',
#  'think democrat okay',
#  'wonder iran russia want biden win',
#  'biden makes money countries fact',
#  'price going make wear mask',
#  'biden made huge mistake opening door',
#  'make joe answer emails',
#  'deal lying',
#  'trump billionaire businessman life meanwhile joe politician shitty one fo',
#  'sadly joe better',
#  'wow bet people stoked enrolling bidencare',
#  'done anything damn near  years joe',
#  'joe biden reminded joe biden',
#  'best stimulus reopening america',
#  'yep stop funding illegals tax dollars',
#  'joe cares cops ha',
#  'raising minimum wage kills jobs small businesses going dem tyrants reopen',
#  'build wall',
#  'want separated come illegally',
#  'biden denied coyotes bring illegals across border lie night',
#  'maybe obamas cage maker help us build wall',
#  'said wants amnesty  million illegals americans struggling work jo',
#  'new talk resisting arrest martyrdom',
#  'I white parents white taught respect law enforcement maybe new talk',
#  'let felons anyones campaign promise period',
#  'laptop hell',
#  'blm terrorist organization',
#  'joe actually thinks trump abraham lincoln',
#  'best way go jail break law pretty freakin damn simple',
#  'biden going kill jobs period raise taxes period',
#  'lie century',
#  'joe biden keep country shutdown I discuss varneyco  mins foxbusiness',
#  'attention joyannreid said blm never called attacks police',
#  'realrlimbaugh pray love many us owe gratitude talk radio',
#  'hpoutx even though officer waller shot line duty still made roll call via facetime motivated please pray',
#  'realdonaldtrumps performance final debate best ever done despite fact e',
#  'tomorrow  days away election day jessebwatters live brand new watters world',
#  'wattersworld tomorrow  days away election day jessebwatters live brand new watters world',
#  'joe afford mistakes thefive',
#  'going kill jobs raise price pump biden saying would transition yous away oil',
#  'varneyco last nights debate biden proposed raising minimum wage even small businesses struggle survive loc',
#  'prominent leftists started calling truth reconciliation commission reverse harm think tr',
#  'setting record straight whoopi goldberg',
#  'theissueisshow promises made promises kept realdonaldtrump booming economy historically low unemployment many gr',
#  'foxla aftermath thursdays presidential debate conservative tomi lahren progressive brian tyler cohen make closing pitc',
#  'stories us gina florio must watch discover must share well',
#  'hunter bidens business partner breaks silence exposing biden family leveraged name make milli',
#  'tonights show profoundly life changing deeply disturbing manner replaced exact',
#  'elexmichaelson podcast fans full unedited debate briantylercohen tomilahren streaming podcast form',
#  'kausmickey would make short election night',
#  'watters world one hour away jessebwatters sentedcruz tedcruz live coverage president trumps ral',
#  'think twitter trying manipulate look right happening',
#  'wattersworld watters world one hour away jessebwatters sentedcruz tedcruz live coverage president trumps rally',
#  'cortessteve jessebwatters better half two three us wattersworld tonight tune fox news',
#  'watters world live jessebwatters sentedcruz tedcruz cortessteve charliekirk dennisprager',
#  'wattersworld watters world live jessebwatters sentedcruz tedcruz cortessteve charliekirk dennisprager dloesch',
#  'mercurycharity virtual gala live watch entire event',
#  'president accurately framed joe lockdown artist kill recovery message biden',
#  'wattersworld president accurately framed joe lockdown artist kill recovery message biden allt',
#  'cortessteve race shapes morning america vs dark winter joe biden insipid combination nurse ratched',
#  'censor gets censored',
#  'something happen joe biden via youtube',
#  'peter retweeted various versions nuns photos  times rather stuff one might th',
#  'know interesting story today nowhere found quite feet',
#  'surprised twitter amplified false damaging frame job borat targeted guliani bur',
#  'tvnewshq watch foxs jessebwatters biden scandal trumps cornered media media reports biden scandal',
#  'tvnewshq fox news jessebwatters trumps closing hard momentum win',
#  'elexmichaelson tomilahren briantylercohen get heated immigration brian child separation trump admin policycruelt',
#  'imagine person',
#  'tellmichelle tune themichellemortensenshow  pacificeastern monday best dang conservative talk show around',
#  'billfoxla remember dire sounding prediction ca state officials last month never happened hospitalizations went dow',
#  'rsscottbp fooled halloween activists dress like journalists try convince  miles',
#  'mrdavidangelo peep show',
#  'ingrahamangle four years georgegeorge',
#  'left convince vote horrible incoherent candidate virus china',
#  'welcome lilpump trump train',
#  'time magazine promoting world economic forums great reset capitalism',
#  'leftist tech companies work hard shadow ban censor silence trump supporters',
#  'dr fauci joe biden favor mask mandates imagine living country federal',
#  'tony bobulinski says met joe biden china media suppressed story real',
#  'studoesamerica thrilled janicedean show tonight talk many failures governor cuomo',
#  'joe biden windelaware thefive',
#  'imagine awkward biden family thanksgiving going loses thefive',
#  'democrats actually managed keep joe biden basically basement election look',
#  'promises made promises kept winning streak continues continue way next tuesday justiceacb',
#  'sick tired democrats telling say think vote freedom vote realdonaldtrump',
#  'democrats party tells many people invite thanksgiving',
#  'glfop nbcnews failed mention key information suspect ran officers armed knife attem',
#  'still unfortunate enough reside communistwannabe state california hope',
#  'democrats win last election yous constitution know time take',
#  'one week retire joe biden back basement quite frankly think would rather',
#  'dems tell us voter fraud real',
#  'claytravis weeks wins losses guest tomilahren comments fun go listen',
#  'democrats say want expand supreme court rotate justices make seats republicans st',
#  'brand new awesome podcast johnny rotten endorsing donny rotten trump one',
#  'donaldjtrumpjr holy shit biden compromised audio evidence hunter biden admitting partnership spy c',
#  'thing happening happened  media thefive',
#  'call news network cover news thefive',
#  'biden looks weak like control base base total control thefive',
#  'glfop brothers sisters philadelphia stay safe vigilant hold line please pray phillypolice le',
#  'elizabeth warren joe bidens treasury secretary recipe greatest depression america ever se',
#  'media suppressed tony bobulinskis story share details meeting joe biden',
#  'deborahglick wrong',
#  'hunter bidens exbusiness partner tony bobulinski remember looking jim biden saying guys ge',
#  'sick democrat leaders standing standing cities looted burned time stop',
#  'nra jack wilson stephen willeford stopped church shootings texas guns right good guys w',
#  'praying officers philly tonight may god protect love bluelivesmatter',
#  'care mention brave innocent honorable law enforcement officers philly holding line',
#  'davidbrodycbn water cooler today alyssafarahfrom whitehousealso tomilahrenhope join pm et across th',
#  'conservmillen democrat campaign ad need see year',
#  'sick told businesses operate crazy covid infringements illustrio',
#  'catching hearings today stands reminder options like check',
#  'voter fraud real much big tech wants censor stories important keep posting sh',
#  'nyt reporter claimed conservatives exaggerating lootingviolence philadelphia blazetvs',
#  'flu deaths twothirds fiveyear average could labeling everything covid',
#  'outkicks whitlockjason shared longtime democratic mother reacted finally saw side',
#  'seano tell funny watching doughboy chase tail',
#  'biden family business chinese communist spies fbi surveillance thefive',
#  'reporting biden corruption scandal yet tonight new recordings biden business pa',
#  'ya go',
#  'bucksexton vote republican party riot party tough choice',
#  'oh man soooooooooooo miles',
#  'joe biden elected democrats get senate country transform speed never seen bef',
#  'yeah floated idea idiots mocking impeachmentitis daily beast either hires profoundly clue',
#  'damning hunter biden documents suddenly vanish',
#  'hopeless goober could see joke took piss cereal',
#  'rubinreport allowed public',
#  'foxnation tomilahren congratulates newly sworn supreme court justice amy coney barrett discusses believes sta',
#  'believe cops allow stabbed justice might democrat',
#  'militant woke every organization twitter cowering get twitter return normal',
#  'matter joe biden claims green new deal modern democratic partys platform words',
#  'left already laid foundation ending filibuster creating new states abolishing electoral',
#  'guy still employed silly answers',
#  'brilliant beautiful mother  became newest justice nations highest court yet vanit',
#  'imagine grace next cover',
#  'clear behind law enforcement joe biden american people choice law order',
#  'going love ginas story joins radio soon whole series fantastic',
#  'maajidnawaz  million followers twitter somehow problem',
#  'surprised public figures start showing outward support realdonaldtrump audacity',
#  'abolishing electoral college major democrats insisting end america know make sm',
#  'billfoxla businesses forced shut absolutely without question given pro rated refunds',
#  'past  years winner florida wins election realdonaldtrump looks like good shape',
#  'lockdowns looming joe wins going lockdowns realdonaldtrump wins thefive',
#  'riot season continues imagine president biden final thoughts',
#  'like racist full stop',
#  'senmikelee great talking glennbeck today big tech bias threats republic',
#  'welcome aboard trump train',
#  'honored inducted radio hall fame tonight listen',
#  'big tech giants nothing street gangs trying run town many politicians left',
#  'waiting back stage happy markandbrian listen live glenn beck gets inducted  radio hal',
#  'another journalist censored thought greenwald brave journalist call crazy rec',
#  'boy twitter tried stop retweeting three times know good news trump',
#  'thank ericrweinstein time expose clean house deep cleaning nd rd string bu',
#  'elect democrat got riot season year round',
#  'missing hunter biden documents suddenly reappeared still lot questions',
#  'attention liberals',
#  'thanks let us congratulate father next week realdonaldtrump',
#  'usbpchief hidden within thegroups women children attempting blend smugglers background checks ar',
#  '  books every book written nyt best seller list stopped counting want',
#  'bet suppressed dloesch always target',
#  'cvpayne morning jack dorsey take  million hit net worth think cares twitter shareholders b',
#  'foxnation man cannot fix mans problems god country music star johnrich opens faith future count',
#  'brettfavre vote makes country great freedom speech religion nd amnd hard working tax paying citizens pol',
#  'billfoxla driving downtown laso many businesses boarded process boarding thing happening beverly',
#  'election drrepstein set largest big tech monitoring system date finding dis',
#  'silly horns always work better loud horns silly horn deadly',
#  'tomorrow  days away election day state race donaldjtrumpjr join watte',
#  'wattersworld tomorrow  days away election day state race donaldjtrumpjr join watters wo',
#  'joe biden closing michigan minnesota seem like strong close thefive',
#  'marclamonthill congrats',
#  'big tech factcheckers censor us want taking peoples words actions plans face va',
#  'marclamonthill would way',
#  'pretty good translation biden speech right',
#  'look folks',
#  'mostly peaceful halloween',
#  'think big tech control wait',
#  'worth every minute',
#  'tonight jessebwatters live coverage president trumps rally battleground pennsylvania',
#  'wattersworld tonight jessebwatters live coverage president trumps rally battleground pennsylvania donaldjtrump',
#  'election day  days away president trump holding four rallies today donaldjtrumpjr reactio',
#  'wattersworld election day  days away president trump holding four rallies today donaldjtrumpjr reaction',
#  'covid far thing plaguing nation seemingly neverending shutdowns job losses shuttered',
#  'nickgillespie happening everywhere neighborhood wood amazon rainforest tells us two',
#  'yous economy president trump roars back lockdowns shattering gdp records laraleatrump watte',
#  'innocents beheaded aps take',
#  'wattersworld yous economy president trump roars back lockdowns shattering gdp records laraleatrump watters wo',
#  'mayor nyc abandons citizens time need rich support mind ca',
#  'watters world live one hour coverage president trumps rally battleground pennsylvania',
#  'watters world live coverage president trumps rally battleground pennsylvania donaldjtrumpjr',
#  'wattersworld watters world live coverage president trumps rally battleground pennsylvania donaldjtrumpjr laraleatr',
#  'good heavens become people daughter wanted make sure gave vegan allergy friendly',
#  'democratic party going far left rubinreport host dave rubin argues pushing average democrats',
#  'halloween counter play vegan candy full size bars whole  pack full size',
#  'people make trump powerful going win reelection people turn outif vote ele',
#  'wattersworld people make trump powerful going win reelection people turn outif vote election',
#  'heytammybruce coming soon jessebwatters tonight foxnews',
#  'wattersworld people make trump powerful going win reelection people turn outif vote election',
#  'everything know love america stake election everyone get vote',
#  'wattersworld everything know love america stake election everyone get vote donald',
#  'trump supporters welcome biden bus texas',
#  'halloween beck house trick treaters loved salute potus trumplandslide',
#  'tvnewshq everything know love america stake election donaldjtrumpjr tells foxs jessebwatters',
#  'tvnewshq watch foxs heytammybruce jessebwatters reveal defining moments president trumps first four years',
#  'tvnewshq watch fox news jessebwatters president trump surging election day lot momentum backtoback',
#  'always adorable ny times discovers millions people exist outside readershi',
#  'posted photo',
#  'closest  point race I ever seen thefive',
#  'dave rubin rubinreport explains media loves republicans neutered flaccid win',
#  'monologue election violence',
#  'enthusiasm joe biden even less kamala president trump win landslide unless',
#  'must read autocratic future united states',
#  'dimartinobooth global scope power unseat dollar',
#  'donaldjtrumpjr clown never thought I would see entire main stream media complex lie badly pour much fuel fires',
#  'sign people believe trouble ahead',
#  'dineshdsouza hunter biden smartest guy joe biden ever met come campaign trail whereshunterbiden h',
#  'benshapiro openly making argument inequality outcome inequity called communism',
#  'conceptualjames question still really think biden going rein wokeness like really',
#  'ritapanahi frightened hungry',
#  'bucksexton utterly moronic yell believe science strangers guess ok',
#  'imamofpeace pakistani politician islamist imam khadim hussain rizvi demands pakistani government uses atomic bombs',
#  'conceptualjames mean literally figuratively take seriously',
#  'expertise reading stuff people agrees shit stolen burned',
#  'hey biden voters hope like radical kamala elect joe get kamala socialist radicals shaping country',
#  'green new deal end fossil fuels defund police covid lockdowns shutdowns amnesty open borders raise taxes g',
#  'ask people venezuela wish could go back way make mistake tomorrow vote realdonaldtrump',
#  'realdonaldtrump first president feel fighting america trump campaign se',
#  'cool keep saying realdonaldtrump polls wait make media look stupid',
#  'every single band slash roster good great could say label',
#  'holy shit',
#  'go ahead underestimate realdonaldtrump supporters fun trumplandslidevictory',
#  'trump looks optimistic wellenergized focused foxnews',
#  'think campaigns know tomorrow night going win whether network declares victory',
#  'yes meant',
#  'final tucker carlson tonight election day starts  minutes pm et foxnews hope watch',
#  'one day biggest election lifetimes strangely feel peace hope president trump wins b',
#  'thadmccotter true disagree methen sirare',
#  'donald trump always living indictment people run country true four year',
#  'massive crowds trump rallies huge indicator way thing going go countless folks tha',
#  'foxnation tomilahren shares message americans ahead election day put trust something bigger',
#  'vote biden vote socialism I discuss foxfriendsfirst next',
#  'big election day show elijahschaffer joins white house s protesters expected today',
#  'usnavy elijahschaffer stevedeaceshow realdonaldtrump kirstiealley am et',
#  'kirstiealley glenn beck I see morning',
#  'elijahschaffer I am et',
#  'today great day win trump',
#  'today decide freedom control',
#  'predict trump landslide silent majority loot riot vote I discuss varneyco foxbusiness next',
#  'contribute least want socialism',
#  'thanks watching',
#  'like joe biden person let retire basement eat jellof watch soap ope',
#  'tweet us questions comments pics watching blazetv blazeelectionstream may see',
#  'today day generation americans votes presidential candidate whether th',
#  'foxnation seanspicer sits tomilahren explain reasoning competing dancing stars shares wa',
#  'kirstiealley shares feuding cnn fear dying coronavirus coverage need',
#  'realdonaldtrump lose supporters go work tomorrow everyday bi',
#  'today decide liberty control choose wisely final thoughts',
#  'fact even board freakin petco brace biden loss unbelievable look far left fallen trump',
#  'varneyco election day finally think win presidency tomilahren prediction says',
#  'florida let us go trump',
#  'president trump thing standing us socialism trump',
#  'nevada want reopen make freakin living got vote realdonaldtrump',
#  'theblaze watching blazetvs electionnight coverage got glennbeck stevedeaceshow conservmillen eri',
#  'anyone would vote keep economies closed raise taxes special kind nuts liberalism mental disorder',
#  'lose confidence trump breaks early blue republican voters get work went vote facts',
#  'usa loves trump',
#  'shock media underestimated realdonaldtrump understand americans outside california ny',
#  'crooked activist election officials starting get nervous look mailin votes',
#  'claytravis know left wing media polling industry ever recovers really',
#  'liberal tears starting flow already blame others perhaps realize',
#  'let us finish trump',
#  'libs leave lib states suck mismanaged move red states vote libs suck',
#  'libs stay lib states ruined stay hell going ruin',
#  ' paying attention know comes next st ask realdonaldtrump mi sc ga w',
#  ' va called early biden state close call find fairfax county prog',
#  ' nothing fox news absolute chaos called az biden said may take back',
#  'erictrump since twitter censoring realdonaldtrump',
#  ' time antifa triggered dc call assassination blaze reporter',
#  ' violence use guns govt trump supporters taking control government buildings havi',
#  ' outlined back  listen tomorrow radio see fight win courag',
#  'bucksexton notice ballot counting shenanigans happening democrat strongholds states democrats behind la',
#  'california model spreading across country need flip things blue always',
#  'left weaponized coronavirus push mailin voting fraudridden method easiest manipulate thi',
#  'stevedeaceshow go glennbeck bottom hour',
#  'erictrump nothing see friends',
#  'pnjaban till legally cast votes counted people lawyers battleground states',
#  'tomfitton twitter interfering election disputes realdonaldtrump',
#  'left believes moral obligation win means necessary believe socialism thei',
#  'honestly fact single person would vote man promises raise taxes know state',
#  'left showing us even possible loot election',
#  'hearing lot folks talk sharpies instructed use az mark read anyone verify',
#  'warned way back february coronavirus ca model spread nationwide',
#  'thought oregon already lost control first state decriminalize possession small amou',
#  'rubinreport remember said monday glennbeck well',
#  'tonight pm et foxnews',
#  'erictrump pennsylvania',
#  'left hate realdonaldtrump hate every single one supporters showing',
#  'congrats youngest representativeelect decades cawthornfornc ready fight america',
#  'going loot riot damn sure going keep fighting going steal brazenly',
#  'florida able count votes quickly states like nevada billoreilly says would',
#  'four years going cooked polls accountability industry thefive',
# ...
#  'sad thing commifornia even care corruption disgusting',
#  'sentedcruz tune am ct I talking glennbeck election results importance protecting',
#  'concerns grown dominion voting system texas rejected election texas gop chairman',
#  'I back today lovely day gardening landscaping built would lie',
#  'ticketmaster may require proof vaccination negative covid test attending events may even nee',
#  'mining wood products machinery great things assault georgia joe biden president',
#  'president realdonaldtrump wants run  could biggest comeback story ever thefive',
#  'realdonaldtrump galvanized silent majority forgotten americans never silent forgotten',
#  'venezuelan timeline success socialism sounds eerily familiar',
#  'alissabatts love theblaze around since inception glennbeck left fox news get  annu',
#  'rubinreport glennbeck studoesamerica sickest radio studio I ever',
#  'elizabeth warren says biden bypass congress president impose progressive wish list',
#  'elites tyrannical rules duh',
#  'tomorrow mustsee watters world newtgingrich sarahpalinusa miss foxnews pm et',
#  'wattersworld tomorrow mustsee watters world newtgingrich sarahpalinusa miss foxnews pm et',
#  'technology expert jeff brown explains major concerns security dominion voting systems',
#  'fantastic show coming way join join live chat show',
#  'america great',
#  'clark county election officials accepted one persons signature eight times las vegas reviewjournal',
#  'tonight mustsee watters world jessebwatters newtgingrich realcandaceo tomfitton',
#  'future mailin ballots former speaker house newtgingrich jessewatters discuss tonig',
#  'nothing looted nothing burned imagine',
#  'wattersworld future mailin ballots former speaker house newtgingrich jessewatters discuss tonight f',
#  'democrats media threatening retribution trump supporters idea unity mustsee rea',
#  'wattersworld democrats media threatening retribution trump supporters idea unity mustsee reaction',
#  'cablenewswatch wattersworld w jessebwatters sets sail pm et foxnews tonights voyage newtgingrich realcan',
#  'wattersworld tonight mustsee watters world jessebwatters newtgingrich realcandaceo tomfitton andrewcmccarthy',
#  'fraud investigation watters world tomfitton andrewcmccarthy break legal challenges team',
#  'wattersworld fraud investigation watters world tomfitton andrewcmccarthy break legal challenges team trump',
#  'president trump going away anytime soon said head gop decades come congres',
#  'wattersworld president trump going away anytime soon said head gop decades come congressman',
#  'show every bit great smells',
#  'joe biden installed many people asking question big tech big media big money trying dr',
#  'dozens videos one sicker next makes wonder would rea',
#  'obama says politics took dark turn mccain picked sarahpalinusa vp mustsee reaction wat',
#  'wattersworld obama says politics took dark turn mccain picked sarahpalinusa vp mustsee reaction watters',
#  'wattersworld joe biden installed many people asking question big tech big media big money trying drag',
#  'jennycongress people viciously assaulted hey fun integrity',
#  'one hour away mustsee watters world jessebwatters newtgingrich realcandaceo tomfitton',
#  'wattersworld one hour away mustsee watters world jessebwatters newtgingrich realcandaceo tomfitton andrewcmccar',
#  'jaketapper homesforourtrps ebay current bid  bucks wife said would pay much get shut',
#  'mikede fastpoose jennycongress thank people overlook happening allies preferring dunk twitter',
#  'far bids stuck  bucks surely better hell I bid higher talk',
#  'russellwiley wounded veterans douchebag',
#  'acceptable behavior spent  years calling victims nazis',
#  'watters world jessebwatters newtgingrich realcandaceo tomfitton andrewcmccarthy',
#  'wattersworld watters world jessebwatters newtgingrich realcandaceo tomfitton andrewcmccarthy mattgaetz n',
#  'megynkelly actual journalist',
#  'something feel right joe biden earn really even campaign',
#  'gunna live chat',
#  'missed original airing watters world worry reair jessebwatters',
#  'wattersworld missed original airing watters world worry reair jessebwatters newtgingri',
#  'wattersworld something feel right joe biden earn really even campaign',
#  'one day voted joe regret voting agenda rob freedom',
#  'last time trust watch fox take join us use pro',
#  'believe moral right attack us else expect loving tolerant left libera',
#  'coming one reasons elite left make sure donald trump would president',
#  'joe bidens call unity feels like demand conservatives surrender left megynkelly argue',
#  'last thing want say told sadly saw coming lived california wh',
#  'jimjordan cancel thanksgiving cancel christmas cancel lockdowns',
#  'lovely twitter election disclaimers remind libs president last  years',
#  'rubinreport truly like interview I done glennbeck brought artifacts documents past told history behin',
#  'quickly turned communist wannabe nation sick',
#  'email producer sent sens warren klobuchar look forward response',
#  'lawyer alandersh argues trumps chance victory house representatives electoral',
#  'hmmm almost like greasy gavy punishing flipping seats back red',
#  'republican mayor governor imposes single additional covid infringement recalled immediately',
#  'joe bidens top state media appointee richard stengel said using propaganda',
#  'tvnewshq fox news jessebwatters tells dems election challenges guys bit patient let play',
#  'hawleymo I heard facebook whistleblower revealed facebook google twitter coordinate censor facebook',
#  'socialism like free shot sounds goodbut pay next day thefive',
#  'want save america must follow strategy mlk gandhi morally justified defend ourselv',
#  'I parler glennbeck look forward seeing along several blazetv hosts',
#  'carolinebrehman million maga march dc earlier today',
#  'thank msm sneeze mightier sword shiv gun molotov cocktail antifa mob see w',
#  'one forced anyone take debt forced collegedebt socialismkills maga',
#  'hmmm need told build back better genius flows tongue like',
#  'reason please let would beautiful big',
#  'wizardpredicts good vs evil',
#  'heckyessica know',
#  'find funny said media needs context clip might show whole story',
#  'knssradio am janice dean fox news senior meteorologist topic gov cuomo nursing home failure glennbeck knssradio',
#  'well lovely',
#  'silent majority longer silent final thoughts',
#  'made feel selfish clinging rights bs never apologize defending freedom',
#  'janicedean grateful glennbeck studoesamerica talk nygovcuomo many media outlets afraid',
#  'strong evidence bidens team devoted great reset left another round lockdown',
#  'update never heard back',
#  'state rep mark baisley good man thank daring tell truth trusting people color',
#  'never late benjysarlin know still enough chalk',
#  'ritapanahi adorable',
#  'combine big tech big media big tech makes someone like biden bulletproof big media attacks tr',
#  'suspicious ga recounts foxnews',
#  'loved happy gilmore',
#  'tech security expert jeff brown actually read manual dominion voting machines says dominion',
#  'vote democrats get tyranny',
#  'big tech want know truth would never vote democrat',
#  'surprise mitt romney joins democrats putting fiscal conservative back dollar gold',
#  'hotel california',
#  'really going abandon people nigerias christians become target genocide international com',
#  'brave police officers much year owe better new episode interruption',
#  'even americas current state still freest people earth us stay way',
#  'south dakota whole family lives south dakota tell ya south dakotans live fear',
#  'mschlapp go another lockdown harms health children blue states continue bleed common',
#  'taking advice taking advice foxnews',
#  'need integrity elections I seen georgia make feel good foxnews',
#  'foxnation tomilahren speaks joshbilicki ltrandysutton importance supporting law enforcement discusses josh',
#  'keith finally useful',
#  'everything comes two senate runoffs georgia left wants pass candidates moderate',
#  'studoesamerica usually post ep title image around time screw patrick newsom  guess talking',
#  'hey rcgov suggest implement mask mandate rapid city vote I personally help hometown',
#  'go ahead try push tyranny rapid citysee well works california buddy south',
#  'pastor democratic candidate georgia senate runoffs rafael warnock told congregation trum',
#  'gotten comfortable tyranny even recognize anymore government closing',
#  'georgia democratic senate candidate john ossoff may try sound moderate groups endorsing suggest oth',
#  'realjonriley joke hits sides give liberty give death freedoms reality freedom risk',
#  'liberal fleeing state ruined liberals please bring liberal policies votes',
#  'knssradio glennbeck knssradio sharyl attkisson investigative reporter topic book slanted news media taught us',
#  'democrats wrongfully blame realdonaldtrump china virus yet states run democrats like ca',
#  'governor greasy gavin hypocrite tyrant newsom caught overcapacity dinner party kn',
#  'claytravis mayor nashville prohibited gatherings eight people inside homes yards outdoors thanks',
#  'say louder people back repmcclintock spot',
#  'think americans willing take orders try exchange australia',
#  'travishollman  agree america land free incentivize vulnerable stay home safe let rest',
#  'pennsylvania extended mask mandate private homes insanity',
#  'daily reminder endvoterfraud',
#  'remember whole russia collusion thing zero eyewitness testimony say saw trump campa',
#  'truly socialist hack since seem get let fill worst kept american sec',
#  'takes office joe biden wants ban new sales assault weapons institute buyback program require',
#  'tyranny continues california elites whatever damn well please',
#  'never quibbled four years helped undermine previous election guess letting',
#  'chsommers exactly',
#  'proud mom standing speaking mask mandate hometown mayor mayorallender',
#  'people want defund police busting thugs deviants also want police enforce bs',
#  'one thing sure sensherrodbrown virtue signaling moron  feet away closest person st',
#  'yasmohammedxx used used justify hijab wife beating sexslaves hating jews disgust gay ppl superiority',
#  'laralogan right seems journalist taken many blows head',
#  'peterboghossian one honest men know knows believes stand defend itbut w',
#  'shocked almost never happens except almost always',
#  'realdailywire french president emanuel macron slams yous mainstream media legitimizing violence',
#  'first time wish like french least love respect country histo',
#  'abbyjohnson I sure msnbc desperate hire footing bill student loans',
#  'way vince vaughn brilliant new jasonblum movie freaky funny enough jump still',
#  'amen could attend one semester yale divorce could afford goi',
#  'eodsteve goldman sachs said week dollars value drop  soon due biden worl',
#  'big radio show today bill ofreilly ny sheriff comply cuomos covid orders sidney powell',
#  'janicedean interview glennbeck studoesamerica earlier week theblaze grateful help',
#  'jimjordan lockdown country impose curfews close schools let americans decide celebra',
#  'gavinnewsom beholden rules wants taxpayers bailout state ruined state',
#  'sidneypowell president trumps legal team tells start putting documents online early',
#  'westjournalism worst covid lockdown yet dem governor bans gatherings inside homes tomilahren',
#  'studoesamerica excited tonights show got extended interview incomparable whitlockjason miss',
#  'tomorrow watters world election fraud investigation want miss team uncovere',
#  'wattersworld tomorrow watters world election fraud investigation want miss team uncovered',
#  'best quality sadly',
#  'left lot things thankful thanksgiving',
#  'update reporting sidney powells voter fraud investigation watch',
#  'yet lives twitter feel like something cops might find wall small shipping conta',
#  'grotesque nygovcuomo killed elderly nursing homes decree move covid patients nurs',
#  'jjosephwilliams seeing article atlantic morning shines light importance govbilllees leadership pas',
#  'rubinreport clearly sidney powell either going drop mother bombs court self immolate go th',
#  'tonight mustsee watters world jessebwatters loudobbs jimjordan jennaellisesq sarahhuckabee',
#  'wattersworld tonight mustsee watters world jessebwatters loudobbs jimjordan jennaellisesq sarahhuckabee heyta',
#  'jennaellisesq wondering exactly process going teamtrump watch indepth discussi',
#  'democrats investigated  election  years finding nothing want question ',
#  'wattersworld democrats investigated  election  years finding nothing want question  elect',
#  'holiday season government overreach gone wild governors tighten coronavirus restrictions ignore',
#  'wattersworld holiday season government overreach gone wild governors tighten coronavirus restrictions ignore ru',
#  'fact elected even unelected government officials think make health safety decisions us',
#  'watters world investigates dominion attorney president jennaellisesq watters world',
#  'wattersworld watters world investigates dominion attorney president jennaellisesq watters world need',
#  'joe biden continues get softballs press sarahhuckabee heytammybruce mustsee reaction',
#  'wattersworld joe biden continues get softballs press sarahhuckabee heytammybruce mustsee reaction w',
#  'roughly  hours dynamite packed hour entertainment throw face pass',
#  'politics thanksgiving tips navigate heated discussions raymondarroyo tonight foxnews',
#  'wattersworld politics thanksgiving tips navigate heated discussions raymondarroyo tonight foxnews pm et',
#  'mustsee watters world one hour away jessebwatters loudobbs jimjordan jennaellisesq',
#  'wattersworld mustsee watters world one hour away jessebwatters loudobbs jimjordan jennaellisesq sarahhuckabee',
#  'mustsee watters world jessebwatters loudobbs jimjordan jennaellisesq sarahhuckabee',
#  'wattersworld mustsee watters world jessebwatters loudobbs jimjordan jennaellisesq sarahhuckabee heytam',
#  'british author douglaskmurray exactly message many americans need hear silent majority',
#  'voters owed fair elections america millions americans died right vote died defending de',
#  'wattersworld voters owed fair elections america millions americans died right vote died defending democrac',
#  'gg show begins I living chatting bit fans well dressed',
#  'missed original airing watters worlddo worry reair jessebwatters',
#  'posted photo',
#  'tired told government knows best enough',
#  'jimjordan receiver knows made catch afraid review director makes good movie af',
#  'allow everyone every business make decisions instead bending backwards com',
#  'douglaskmurray hold back america given world every country history done things',
#  'susanshelley individual restaurant owners fear speak latest bankruptcyinducing shutdown orders could lose operat',
#  'instead forcing officers go dirty work greasy gavinnewsom spends thanksgiving',
#  'deporting criminal illegal aliens saves lives part',
#  'educated guess dineshdsouza think fundraising making lines clear',
#  'read disturbing quote repjimcooper nashville post today care explain mean',
#  'excuse repjimcooper please let south carolina voters know meant saying extra ch',
#  'longtime nashville area democrat congressman repjimcooper referred south carolina voters syndrome v',
#  'hey repjimcooper new nashville constituent want know meant quote ask',
#  'different types family members deal thanksgiving covid times thefive',
#  'well would look greasy gavinnewsom mutiny hands perhaps even',
#  'low iq libs trump strong man leave office without use force trump permits transit',
#  'voted democrat better even think bitching lockdowns higher taxes lack basic freedom',
#  'hope spineless fake republicans know days elected office numbered forget',
#  'studoesamerica miss radio show today whitlockjason fills',
#  'sasha mercy whitlockjason dropping word today filing glennbeck theblaze studoesamerica hav',
#  'democrat tyrants crushing livelihoods closing businesses rendering jobless yet keep voti',
#  'psa democrats ruin everything',
#  'reminder democrat repjimcooper compared south carolina voters individuals syndromeno backlas',
#  ...]

# %%
df = pd.read_csv('./data/analysis/Right_labeled.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        date                   id  \
# 0           0             0  2020-10-05  1312907856165826565
# 1           1             1  2020-10-05  1312967247112134656
# 2           2             2  2020-10-05  1313113401120436226
# 3           3             4  2020-10-05  1313167228897030144
# 4           4             5  2020-10-05  1313175357864935425
#
#                                           tweet_text     label
# 0  trump first ran president hard many imagine ro...  Not Hate
# 1  trishregan left realize secret service always ...      Hate
# 2                           dbongino good luck buddy  Not Hate
# 3  jaltucher feel like need restraining order guy...  Not Hate
# 4  msm might want look actual stats cdc next time...  Not Hate
