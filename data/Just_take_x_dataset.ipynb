# %%
import pandas as pd

# %%
df = pd.read_csv("Fake_clean.csv")

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
arr = df.date.values

# %%
arr = set(arr)

# %%
arr.remove('2020-10-05')

# %%
df
# Out:
#             date  ...                                         tweet_text
# 0     2020-10-05  ...  called paying respects people love depend hate...
# 1     2020-10-05  ...                          whenever god shines light
# 2     2020-10-05  ...  webinar tomorrow military readiness face globa...
# 3     2020-10-05  ...  france looks restore influence lebanon iran bu...
# 4     2020-10-05  ...                             song day yon two crows
# ...          ...  ...                                                ...
# 8380  2021-01-27  ...  oldpappythomas hedge fund losing billions redd...
# 8381  2021-01-27  ...  sen cruz bidens un pick praised welcomed china...
# 8382  2021-01-27  ...  charles payne explodes wall street whining sky...
# 8383  2021-01-27  ...             cloris leachman emmy oscar winner dead
# 8384  2021-01-27  ...                                          born free
#
# [8385 rows x 3 columns]

# %%
data = df[df.date == '2020-10-05'].head(30)

# %%
data
# Out:
#           date  ...                                         tweet_text
# 0   2020-10-05  ...  called paying respects people love depend hate...
# 1   2020-10-05  ...                          whenever god shines light
# 2   2020-10-05  ...  webinar tomorrow military readiness face globa...
# 3   2020-10-05  ...  france looks restore influence lebanon iran bu...
# 4   2020-10-05  ...                             song day yon two crows
# 5   2020-10-05  ...  devastating fans blacklivesmatter entertainmen...
# 6   2020-10-05  ...  everything biden says lie going defeat using p...
# 7   2020-10-05  ...  question trumps inner circle seem suddenly con...
# 8   2020-10-05  ...  interesting journey learned lot covid presiden...
# 9   2020-10-05  ...  voice american fascism gets upside usual voter...
# 10  2020-10-05  ...                                       silver eagle
# 11  2020-10-05  ...  yous japan quad mr trump stick important read ...
# ...

# %%
for day in arr:
  print(day)
  
 
  
  #data = .join()

  data = pd.concat([data, df[df.date == day].head(30)])
# Out:
# 2021-01-16
# 2020-12-29
# 2020-12-19
# 2020-12-30
# 2021-01-21
# 2020-12-01
# 2020-12-09
# 2020-11-01
# 2020-12-10
# 2020-11-04
# 2020-11-17
# 2020-12-06
# 2020-12-13
# 2021-01-03
# 2020-10-28
# 2020-12-24
# 2020-12-22
# 2021-01-12
# 2020-10-25
# 2020-12-26
# 2020-11-02
# 2021-01-26
# 2021-01-11
# 2020-10-15
# 2020-10-26
# 2020-11-25
# 2020-10-11
# 2020-11-15
# 2021-01-27
# 2020-10-31
# 2020-11-22
# 2021-01-14
# 2020-10-10
# 2020-10-16
# 2020-11-07
# 2020-11-10
# 2020-11-30
# 2020-10-29
# 2020-10-17
# 2020-10-19
# 2021-01-01
# 2020-12-17
# 2020-10-08
# 2020-10-13
# 2020-11-26
# 2021-01-13
# 2021-01-06
# 2020-10-20
# 2020-11-24
# 2021-01-08
# 2020-11-03
# 2020-12-15
# 2020-12-27
# 2020-12-11
# 2020-12-04
# 2020-10-27
# 2020-10-12
# 2020-11-06
# 2020-11-27
# 2021-01-24
# 2020-11-21
# 2021-01-15
# 2020-11-08
# 2020-11-12
# 2020-11-14
# 2020-10-22
# 2020-10-24
# 2021-01-04
# 2020-12-23
# 2021-01-23
# 2021-01-02
# 2021-01-07
# 2020-11-19
# 2020-11-20
# 2020-11-28
# 2020-10-06
# ...

# %%
data
# Out:
#             date  ...                                         tweet_text
# 0     2020-10-05  ...  called paying respects people love depend hate...
# 1     2020-10-05  ...                          whenever god shines light
# 2     2020-10-05  ...  webinar tomorrow military readiness face globa...
# 3     2020-10-05  ...  france looks restore influence lebanon iran bu...
# 4     2020-10-05  ...                             song day yon two crows
# ...          ...  ...                                                ...
# 1476  2020-11-16  ...                      cnn context clips dc violence
# 1477  2020-11-16  ...                        put hate shelf split second
# 1478  2020-11-16  ...  trump campaign rejects claim dropped key porti...
# 1479  2020-11-16  ...               politico get hopes georgia democrats
# 1480  2020-11-16  ...    securefreedom us army still training chinas pla
#
# [3311 rows x 3 columns]
